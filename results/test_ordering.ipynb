# %%
import pandas as pd
import os

for folder in os.listdir("../mdc_asr_shared_task_test_data"):
    for d in os.listdir(f"../mdc_asr_shared_task_test_data/{folder}"):
        df = pd.read_csv(f"../mdc_asr_shared_task_test_data/{folder}/{d}", delimiter="\t")
        df2 = pd.read_csv(f"~/Downloads/mdc_asr_shared_task_test_data/{folder}/{d}", delimiter="\t")
        assert(df.audio_file.tolist() == df2.audio_file.tolist())
        # print(df.audio_file.tolist()[10:15], "\n", df2.audio_file.tolist()[10:15], "\n")
df2
# Out:
#                            audio_file  \
# 0    spontaneous-speech-lth-28634.mp3
# 1    spontaneous-speech-lth-28555.mp3
# 2    spontaneous-speech-lth-28503.mp3
# 3    spontaneous-speech-lth-28320.mp3
# 4    spontaneous-speech-lth-38897.mp3
# ..                                ...
# 182  spontaneous-speech-lth-28654.mp3
# 183  spontaneous-speech-lth-28205.mp3
# 184  spontaneous-speech-lth-39070.mp3
# 185  spontaneous-speech-lth-37958.mp3
# 186  spontaneous-speech-lth-28472.mp3
#
#                                               sentence
# 0    An atio kï cim karë kïbëc atio kï cim ïgï cany...
# 1    Kwan ölökö bedo ka lwak kï bedo kï lïm ï peci ...
# 2     më gwökërë kï ï kom two myero alwök cïnga kar...
# 3     peki tye na pol ata na dong löö y akinagï kïb...
# 4     kwan okelo nïaö ï pacö na mëga kwan okelo nge...
# ..                                                 ...
# 182   Kwan ömïa nïang nï ka akëm obino mïtö anwën n...
# 183   më könyö thïnö ëk ömak gïnï kwan na tëk enyod...
# ...

# %%
df2
# Out:
#                            audio_file  \
# 0    spontaneous-speech-lth-28634.mp3
# 1    spontaneous-speech-lth-28555.mp3
# 2    spontaneous-speech-lth-28503.mp3
# 3    spontaneous-speech-lth-28320.mp3
# 4    spontaneous-speech-lth-38897.mp3
# ..                                ...
# 182  spontaneous-speech-lth-28654.mp3
# 183  spontaneous-speech-lth-28205.mp3
# 184  spontaneous-speech-lth-39070.mp3
# 185  spontaneous-speech-lth-37958.mp3
# 186  spontaneous-speech-lth-28472.mp3
#
#                                               sentence
# 0    An atio kï cim karë kïbëc atio kï cim ïgï cany...
# 1    Kwan ölökö bedo ka lwak kï bedo kï lïm ï peci ...
# 2     më gwökërë kï ï kom two myero alwök cïnga kar...
# 3     peki tye na pol ata na dong löö y akinagï kïb...
# 4     kwan okelo nïaö ï pacö na mëga kwan okelo nge...
# ..                                                 ...
# 182   Kwan ömïa nïang nï ka akëm obino mïtö anwën n...
# 183   më könyö thïnö ëk ömak gïnï kwan na tëk enyod...
# ...
